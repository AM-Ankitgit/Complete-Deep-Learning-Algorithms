# %% [markdown]
# # encoder in transformer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `here Nx`: mean mulitple encoder and decoder block
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# every `encoder` box contain the `self attention mechanism` and `feed farward NN`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# simplyfied version of the ecoder here we have 6 block of the encoder
# output from one encoder block become input of next encoder block
#
# output of last encoder block became the input for decoder block

# %% [markdown]
# #### Step 1 :
#  input block
#
#  ![image.png](attachment:image.png)
#
# - tokenization
# -  convert the sentence into `vector embedding`(word embedding)
# -  cal postional encoding embedding
# -  vector addition of the `vector embedding and positional encoding embedding `

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### step 2 :
# and vector addition of the positional encoding vector and the embedding vector will the input for the encoder block
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# as we see the we pass the vector to the multihead attention we got the
# z1,z2,z3 and along with that we have the residual connection out out input vector also availbel x1,x2,x3
#
# then we perform the vector addtion of x1,x2,x3  and z1,z2,z3
# and will get the z1`,z2`,z3` and perform the layer normalization
#
#
# ![image.png](attachment:image.png)
#
#
# after normalization we will get the Z1norm, Z2norm,Z3norm

# %% [markdown]
# step 3 : feed farward NN
#
# ![image.png](attachment:image.png)
#
#
# `with two layer `

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#    ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# what is the perpose of doing this because we used activation function relu it mean it help to introduce non linearity in the data and
#
#
#
# after applyiing the feed feedward will geth metrix y1,y2,y3 on
# then will perform the vector addition of the  y1,y2,y3 and Z1norm, Z2norm,Z3norm
# then layer normalization
#
#
# and got the
#
# y1`,y2`,y3`
#
# `which be the input for your next 2nd  encoder block`

# %% [markdown]
# what diffeence between the `each encoder block for each block parameter will be different`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# why multiple encoder block : to get the satisfactory result
#
# one encoder may or may not be give the statisfactory result that why we need the multiple encoder
