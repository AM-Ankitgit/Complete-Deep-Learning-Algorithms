# %% [markdown]
# # Seq to Seq :
#
# ## input and the output has the sequence
#
#
# `Challenge in Seq to Seq` :
#
# len of input data and output varies
#
# eg. translate below sentense in marathi
# Q. Nice to meet you?
# Ans. Aapse mil kar achhha laga
#
# here len of input and output varies

# %% [markdown]
# # Encoder and Decoder arch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Detail Diagram of Encoder
#
# in encoder is made by using one LSTM cell

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Decoder :
# decoder is also made by the LSTM cell
#
# and in decoder has the one special symbol (start)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### how to train the encoder and decoder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  HOW TO DO ENCODING FOR INPUT AND OUTPUT TEXT DATA
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# # Working of Encoder and decoder
#
# convert the your input in to number
#     input:             output
# 1.think about it      soche lo
# 2. come in            andar aa jao
#
#
#
#
# after onehow encoding (total unique word  input is 5)
# your encoding will like wise
# think = [1,0,0,0,0]
# about = [0,1,0,0,0]
# it    = [0,0,1,0,0]
# come  = [0,0,0,1,0]
# in =    [0,0,0,0,1]
#
# output we have two extra word `start` and `end` so total unique word for output is 7
#
# start = [1,0,0,0,0,0,0]
# soche = [0,1,0,0,0,0,0]
# lo =    [0,0,1,0,0,0,0]
# andar = [0,0,0,1,0,0,0]
# aa =    [0,0,0,0,1,0,0]
# jao =   [0,0,0,0,0,1,0]
# end  =  [0,0,0,0,0,0,1]

# %% [markdown]
# now we will feed the input data to encoder and context will remember the
#
#
#  the final hidden state of the encoder (or a combination of all hidden states) is taken as the context vector
#
#  Represents the encoded information of the entire input sequence.
#
#
#
#  input  [1,0,0,0,0] for t=1
#
#         [0,0,0,0,1] for t= 5
#
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# feed data to decoder now
#
# start = [1,0,0,0,0,0,0]
# we get the some ouput like [0.2,0.1,0.3,0.1,0.2,0.01,0.03]
# 0.3 is the highest value out put will be
#
# lo =    [0,0,1,0,0,0,0]
#
# which is wrong (because for the think = [1,0,0,0,0] ouput  should be
# soche = [0,1,0,0,0,0,0])
#
# know for next input will we have to pass the ouput of previous
# lo =    [0,0,1,0,0,0,0]
#  only if the correct otherwise we use the teacher forcing concept to pass the correct input (as per input think = [1,0,0,0,0] we pass the soche)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# after performing the forward propagation calculate the loss and perform the backword-propagation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # `Improvement`
# ### 1 .Embedding for encoder and decoder

# %% [markdown]
# To avoid the mis-prediction we use the embedding and where the teacher forcing will not use.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can use the embedding two ways
# 1. use the pre-trained (word2vec/glove) embedding
# 2 .create your own embedding from your data (it will help to learn all nuance inormation )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2 .Deep LSTM

# %% [markdown]
# ![image.png](attachment:image.png)
#
# it help long term dependecy

# %% [markdown]
# accurarcy is measured in BLEU score (it is matrix)
