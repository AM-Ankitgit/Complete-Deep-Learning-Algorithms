# %% [markdown]
# # Loss Function
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# why we need squared : To make everything positive (if we get negative difference the it will not add to the next error it subtraction instead of adding)
#
#
# - Adv: Mse is differential
# - Dis: it is Not Robust to outliers (why: when we get the prediction  it will be wrong and new weight will update drastically mean it try to capture the this outlier point it will make loss the true nature of the your data   )
#
# - we penalize the outliers
#
# - if have the outlier do not use the MSE
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hubber Loss: is the combination of MSE AND MAE
#
# if the data has outlier then it will behave as MAE
# If the datahas No  ouliter then it will behave as MSE
#
#
# by combine the MSE and MAE : huber loss will give property of  in between  of MSE and MAE
# ![image.png](attachment:image.png)
#
# here delta is hyperparameter which will handle the outliers

# %% [markdown]
# ![image.png](attachment:image.png)
#
# also call as the log loss
#
# in DL : in output layer
# - for binary classification should have the sigmod activation function
# - for multiclass classification >>>>>>>>Sofmax

# %% [markdown]
# ![image.png](attachment:image.png)
# it Not intuitive

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What is difference between the Sparse Categorical Cross Entropy and Categorical Cross Entropy
#
# Categorical Cross Entropy : target the columns is onehot encode 1 0 0
#                                                               0 1 0
#
#  Sparse Categorical Cross Entropy : 1
#                                   : 2
#                                   : 3
#
# ![image.png](attachment:image.png)
#
#  Sparse Categorical Cross Entropy : Fast because it call loss of the that label(1,2,3) those record we are training
#
#  ![image-2.png](attachment:image-2.png)
#
#  remaining will be zeros
