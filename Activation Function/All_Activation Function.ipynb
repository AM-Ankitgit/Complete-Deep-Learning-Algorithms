# %% [markdown]
# # Sigmoid Function
#
# second graph is the derivate of sigmoid
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `why we Don't use the Sigmoid in hidden layer`
#
# - because it is saturating function mean it squeeze the your input Sum(w1X1+w2X2) from any value to [0,1]
# - because this we face the vanishing gradient problem
# - look at graph-2  if the value of X increase after -3,3, the value of the derivative is zero , it means derivate of weighted sum (Sum(w1X1+w2X2)) of input became zero
#
# their is no weight updation Wnew = Wold
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - only it is used in binary classification in output layer
# - it is NON-ZERO centric function
# ![image.png](attachment:image.png)
#
#
#      if we use the activation in the mean value activation function !=0 (it mean it not normalizes)
#      training is slow >>> conversion is also slow
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font color='green'>Tanh Activation Function or  hyperbolic tangent function </font>

# %% [markdown]
# `Zero Centric`: mean derivative of activation function provide both positive and negative gradient
#
# second graph is the derivative of Tanh

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Value of Tanh is in range of [-1,1]
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# $\color{red}{\text{ciao}}$

# %% [markdown]
# <span style='color:red'>green</span>
# $\color{green}{\text{blue}}$
# <font color='red'>orange</font>

# %% [markdown]
# # <font color='Blue'>Relu Activation Function or rectified linear unit </font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - it is non-zero centric function  : But to solve the non-zero centric function we can use the batch normalization
#
# - it has the dying relu problem

# %% [markdown]
# # `Dying Relu Problem`

# %% [markdown]
# what is dying relu :<br>
# - dying relu mean the your neuron became the dead its not active and once it became the dead it will dead forever so our model will not learn the high representaion  of your input
#
# - there might the chance to dead the all neuron
#
# ![image.png](attachment:image.png)

# %% [markdown]
# `Why dying Relu Problem`
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# for for first neuron(a1) value of activation is then than zero <br>
#
# ![image-6.png](attachment:image-6.png)
#
# z1 = 0
#
# a1 = max(0,z1) =0
#
# derivative of a1 w.r.to z1
#
#
# ![image.png](attachment:image.png)
#
# update the weight
#
# ![image-2.png](attachment:image-2.png)
#
# here loss of L depend on y_hat and y_hat depend on following parameter
#
# ![image-3.png](attachment:image-3.png)
#
# to update w1 it follow the red line path
# so by chain rule derivative of each parameter
#
# ![image-4.png](attachment:image-4.png)
#
# and the value of this term is zero
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# so weigth updation will not happen
#
# ![image.png](attachment:image.png)
#
# Wn = Wo

# %% [markdown]
# why this value became negative .ie <0
#
# ![image.png](attachment:image.png)
#
# - if learning rate is high
# - if high negative bias

# %% [markdown]
# `Solution for dying relu`
#
# ![image.png](attachment:image.png)
#
# use the variant of relu

# %% [markdown]
# Different Variant of Relu
# ![image.png](attachment:image.png)

# %% [markdown]
# `Leaky Relu:`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# here we multiply the with fraction 0.01*Z so the your weight never become zero
# it always keep the weight updation, because this we solve the dying relu problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# disadvantages :  why take the value 0.01 (but it's proven value)

# %% [markdown]
# `Parametric Relu` : it is similar to leaky relu only instead of 0.01 value we add the trainable parameter (a)
#  -means when the model train the value of a is also train (based of given data)
#
#  adv : Flexiblity because of value of a
# ![image.png](attachment:image.png)

# %% [markdown]
# `Elu or Exponential linear Unit`
#
# ![image.png](attachment:image.png)
#
# first formula of Elu
#
# second formula derivative of Elu
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# `Selu - Scaled Exponetial Linear Unit`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# here value of alpha and lambda are fixed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it is self normalized ,mean =0 and std =1
# converges faster
