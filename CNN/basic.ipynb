# %% [markdown]
# # `CNN`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# fc :fully connected
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # use can use ANN but result will not get satisfied
#
#
# image is in form pixel 2D form
#
# what if we use ANN for image classification
#
# `1 .High Computation Cost`:
# (Form  a ANN)
# convert your data in 1D
#
# ![image.png](attachment:image.png)
#
# image row pixel value are arrage in vertically for NN
#
#
# if image has 40*40 =1600 , from the input layer 1600 weight need to compute which will be more costly

# %% [markdown]
# `2 .OverFitting`

# %% [markdown]
# `3. Loss of important info like spatial arrangement of pixel`
#
# ![image.png](attachment:image.png)
#
# when we conver 2d Data into 1D we loss the main feature of image
# like in this image to form the nose we need 2D

# %% [markdown]
# # How CNN Work
# images is collection of pixel
#
# different type of image
# ![image.png](attachment:image.png)

# %% [markdown]
# CNN  model first find
# primitive feature mean edges
# ![image.png](attachment:image.png)
#
# then create complex feature
# like above image it detected semi-circle then after
# join that semi-circle and and farm the full circle
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# From Above image
# - first we move the filter on image and detect the feature from the image which will in first layer(we try to detect the pattern of layer in image)
# if that feature existed in image that feature will be activated and transfer to next layer (to merge feature)
#
# - after that we pass the that feature to next convolution layer and find meaning full feature from that layer this process will be continuous

# %%
#Convolution layer are basically filter to extract the features

# %% [markdown]
# # Application of CNN
# - for image classification
# ![image.png](attachment:image.png)
#
# - object localization: detect to particular object and create frame for this object
# mean detect the particular object from multiple object in image
#
# - object Detection : detect the all object and we frame with probability
# - Facial Image Detection
# - Image Segemention : divide image in region
# ![image-2.png](attachment:image-2.png)
#
# - Resolution : in quality of images
# - Convert the image from black to color
#
# - Poser Detection
# ![image-3.png](attachment:image-3.png)
