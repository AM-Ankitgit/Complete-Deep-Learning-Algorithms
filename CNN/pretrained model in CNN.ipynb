# %%
# why use pretrained models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is ImageNet Dataset :
# The ImageNet project is a large visual database designed for use in visual object recognition software research.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # `ILSVRC`:
# The ImageNet Large Scale Visual Recognition Challenge (ILSVRC) evaluates algorithms for object detection and image classification at large scale.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Alex Net Arch :
#
# AlexNet is a pioneering convolutional neural network (CNN) used primarily for image recognition and classification tasks. It won the ImageNet Large Scale Visual Recognition Challenge in 2012, marking a breakthrough in deep learning.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# in % : it is error rate by the model
# ![image.png](attachment:image.png)

# %% [markdown]
# https://keras.io/api/applications/

# %% [markdown]
# # ResetNet Pretrained model

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from glob import glob
import os
import matplotlib.pyplot as plt

# img_path = r'D:\study\Complete-Deep-Learning-Algorithms\Image_Data\81LCaKEBp2L._SX679_.jpg'

for img_path in glob(os.path.join(r'D:\study\Complete-Deep-Learning-Algorithms\Image_Data','*.jpg')):
    
    img = image.load_img(img_path,target_size=(224,224))
    plt.imshow(img)
    plt.show()

    # do prediction for each images
    x = image.img_to_array(img)
    x = np.expand_dims(x,axis=0)
    x = preprocess_input(x)

    pred = model.predict(x)
    print("Prediction" ,decode_predictions(pred,top=1)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction [('n03792782', 'mountain_bike', 0.9815113)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Prediction [('n04254680', 'soccer_ball', 0.99917275)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Prediction [('n02403003', 'ox', 0.6053209)]

# %% [markdown]
# # Visualization CNN Pretained model of VGG16

# %%
from keras.applications.vgg16 import VGG16

# load the model
model  = VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
from keras.utils import plot_model
plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# we want to check how convolution layer work and create the features map

# need to find the conv layer in model
for i in range(len(model.layers)):
    #check convolution layer

    if 'conv' not in model.layers[i].name:
        continue # stop the current iteration and go for next one

    print(i)
    filters,biases = model.layers[i].get_weights()
    print('layers number ',i, model.layers[i].name,filters.shape)
# Out:
# 1
# layers number  1 block1_conv1 (3, 3, 3, 64)
# 2
# layers number  2 block1_conv2 (3, 3, 64, 64)
# 4
# layers number  4 block2_conv1 (3, 3, 64, 128)
# 5
# layers number  5 block2_conv2 (3, 3, 128, 128)
# 7
# layers number  7 block3_conv1 (3, 3, 128, 256)
# 8
# layers number  8 block3_conv2 (3, 3, 256, 256)
# 9
# layers number  9 block3_conv3 (3, 3, 256, 256)
# 11
# layers number  11 block4_conv1 (3, 3, 256, 512)
# 12
# layers number  12 block4_conv2 (3, 3, 512, 512)
# 13
# layers number  13 block4_conv3 (3, 3, 512, 512)
# 15
# layers number  15 block5_conv1 (3, 3, 512, 512)
# 16
# layers number  16 block5_conv2 (3, 3, 512, 512)
# 17
# layers number  17 block5_conv3 (3, 3, 512, 512)

# %%
# retrieve weights from the second hidden layer
filters , bias = model.layers[1].get_weights()

# %%
# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
n_filters =6
ix=1
fig = plt.figure(figsize=(15,10))
for i in range(n_filters):
    # get the filters
    f = filters[:,:,:,i]
    for j in range(3):
        # subplot for 6 filters and 3 channels
        plt.subplot(n_filters,3,ix)
        plt.imshow(f[:,:,j] ,cmap='gray')
        ix+=1
#plot the filters 
plt.show()

# %%
from tensorflow.keras import Model

model = Model(inputs=model.inputs , outputs=model.layers[1].output)

# %%
img = image.load_img(r"D:\study\Complete-Deep-Learning-Algorithms\Data Agumentation CNN\images.jpg" , target_size=(224,224))

# convert the image to an array
img = image.img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = np.expand_dims(img, axis=0)

img = preprocess_input(img)

# %%
#calculating features_map
features = model.predict(img)

fig = plt.figure(figsize=(20,15))
for i in range(1,features.shape[3]+1):

    plt.subplot(8,8,i)
    plt.imshow(features[0,:,:,i-1] , cmap='gray')
    
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
