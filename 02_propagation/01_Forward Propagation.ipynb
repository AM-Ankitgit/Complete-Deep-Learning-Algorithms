# %% [markdown]
# forward propagation is the process of passing data through a neural network to compute the final output.
# ![image.png](attachment:050f2609-c016-4ee7-9678-c076c9c8be48.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
