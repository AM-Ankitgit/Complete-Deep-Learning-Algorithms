# %% [markdown]
# # Optimizers :
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
#
# ![image.png](attachment:5384dad2-de98-4287-a0d0-00d41fb02f4c.png)
#
# for imporve the performance of model
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# this is also optimzers

# %% [markdown]
# challenges for above GD:
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Optimizers
#
# ![image.png](attachment:image.png)
#
# all this optimizer are developed by improving in GD

# %% [markdown]
# # Exponentially Weighted Moving Average or Exponential Weighted Average

# %% [markdown]
# it is technique to find-out hidden  trends in timeseries based data
#
# ![image.png](attachment:image.png)
#
# beta is constant
#
#
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# for Example  : if we set the beta value 0.9
#
# ![image.png](attachment:image.png)
#
# it means the it we will take average of 10 previous days

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# so beta designed in such way it gives more weightage to new value as compared to previous value

# %% [markdown]
# beta = 1-alpha
