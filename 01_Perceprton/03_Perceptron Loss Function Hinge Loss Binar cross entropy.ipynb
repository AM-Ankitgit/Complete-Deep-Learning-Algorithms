# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# in 2d -perceptron >> line
#
# multidimensional - perceptron will be >> plan

# %% [markdown]
# # Problem With Perceptron Trick:
#
#
# The perceptron only updates the weight when the output produced is different from the target labels. Therefore, if the label is -1 and the output is also -1, the loss for this data is zero. However,
#
# in Perceptron trick we train model below ways
#
# if the point perfectly classified then line will not be move
# if the point misclassified the line will shift toward the point and value of w1,w2,....Wn and b will change
#
# perceptron is fail to tell the how good is your classification(result cannot be quantify)
#
# it may also fail in conversions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Loss Fucntion : it is way to tell how good or bad your model
one record  :we call loss function when will find loss for one record 
more than one record : then we say cost function

# %% [markdown]
# # To Find Loss Function for Perceptron
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# # HINGE lOSS
#
# ![image.png](attachment:c173f493-5b6c-4eb8-b6e7-f18a4706086e.png)
#
# ![image.png](attachment:951c77ad-20be-4d02-a9d5-222655b3201f.png)
#
#
# Gradient Descent is an optimization algorithm used to minimize a function by iteratively adjusting its parameters. It is widely used in machine learning to minimize loss functions, such as Mean Squared Error (MSE) or cross-entropy, during model training. The goal of gradient descent is to find the set of model parameters (e.g., weights in a neural network) that minimize the loss.

# %% [markdown]
# ![image.png](attachment:image.png)
# for two recored
#
# ![image-2.png](attachment:image-2.png)
#
# contribution of loss function in  different way
#
# 1. if the actual and prediction is yes loss function will be zero no contribution of loss
# 2. if actual and prediction is No loss function will be zero, no contribution of loss functions
#
# 3. if the pred is positive or negative then loss function will be contribute some values

# %% [markdown]
# ### Find the  value of W1,W2,b so we can get min loss value of loss
# #### Gradient Descent for Perceptron
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# logistic === perceptron
#
# when the activation function : Sigmoid
# and  loss function is : binary cross entropy

# %% [markdown]
# Perceptron is flexible mathematical fucntion : it can work as logistic regression or linear regression or multiclass classifier only need to manage the activation and the loss function
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# PERCEPTRON DO NOT WORK ON NON-LINEAR DATA
#
# proof:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
# xor  gate : has non-linear dataset

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x=xor_data['input1'],y=xor_data['input2'],hue=xor_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5


plt.plot(x1,y1)
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
# Out:
# <Axes: >
