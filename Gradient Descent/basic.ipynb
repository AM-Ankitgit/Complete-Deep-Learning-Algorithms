# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# from second for loop gradient dscent process started
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Type of Gradient Descent
# ![image-2.png](attachment:image-2.png)
#
#
# - batch
# - stochastic
# - mini batch

# %% [markdown]
# # Batch GD : all data will pass at time and find the prediction
#
# use dot product instead of for loop call as vectorization
#
# ![image.png](attachment:image.png)
#
#
# if the epchos =5 then the five time weight and biases will update
#
#
# for  i in range (epochs):   # only one for loop
#
#    get the prediction for all data
#    and update weight and biases

# %% [markdown]
# Stochastic GD:
#
# this is called as the  Stochastic GD
# here epochs =10
# number of record =50
# then number of time weight updation will be 50*10 = 500 times
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # from Batch and SGD which one is faster
# Batch :Faster (number of time weights updation is less ) (epochs=10 ,then time updation)
#
# SGD : slow because number of time weights updation is high (ephocs=10*number of record=50 =  500)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# numebr of record = 320 : from below code batch_size=320 (same as number of record so it will work as BATCH GD)
#
# - if batch_size = 1 : SGD
# - if batch_size = number of record :  Batch GD
# - ![image.png](attachment:image.png)

# %% [markdown]
# Stochastic will be more efficient for conversion
# ![image.png](attachment:image.png)

# %% [markdown]
# Reducing of loss in SGD is getting fluctuated(Unstable)
# ![image.png](attachment:image.png)

# %% [markdown]
# Reducing loss in BATCh GD is Stable
# ![image.png](attachment:image.png)

# %% [markdown]
# why this unstable loss reducing behaviour>>>>because we use randome record in SGD that is why the loss reduction is unstable
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - if we use the Batch is may stuck in local minima
# - if we use the SGD it may stuck in local minima but will move because of the randomness and will reach to the global minima but it will not give the exact conversion

# %% [markdown]
# # Vectorization

# %% [markdown]
# Vectorization will  not work if we have huge data set because it will not store the whole data at time if data size is huge

# %% [markdown]
# # Mini Batch GD
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# To use the RAM efficitivly(Optimization)
#  ![image.png](attachment:image.png)
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# here total record is 400 and batch size =150
#
# here will 400/150= 2.66 (3 time updation)
#
# ![image.png](attachment:image.png)
