# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# as we do the normalization for your input
# likewise then out of your neuron became the input of next hidden  layer so ,that value should be the normalizes before treating input to next hidden layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# covariance  shift : the relation between the input and output is same but  distribution of data is different called as the covariance shift  because this reason we need to retrain the model

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# here output(Weights) of first two layer constantly getting change to input of last to layer this called as the internal covariance shift

# %% [markdown]
# # How it Work

# %% [markdown]
# - it applicable on Mini-Batcg GD
# - it apply layer by layer
# -
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# how mean (µ) getting calculated
#
# ![image-3.png](attachment:image-3.png)
#
# m= Mini_Batch Size
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# epsilon : we add error term if in case the std =0
# ![image-6.png](attachment:image-6.png)
#
# after getting the normalized value we mulitply the normalize value with gamma and beta
#
# ![image-9.png](attachment:image-9.png)
#
#
# gamma and beta are the trainable parameter
# initial value of gamma= 1
#                 beta =0

# %% [markdown]
# Entire steps
# :
# ![image.png](attachment:image.png)
#
#
# Note if in layer 2 node then this whole process will repeat 2 time including gamma and beta values

# %% [markdown]
# Why we use gamma and beta : in few data case the model dont want to data should be normalized ,gamma give the flexibility for scale and shift if model want data should be normalized or not

# %%
Why it is different for training and testing
because in training we use the  min batch and cal std and mean

but in testing we will have the only one query point then how it will work
>>>>>>>>>. it is use Exponetial Weighted Moving Avergae is used
which mean from the last iteration of training it will store the all the trainable parameter and std , mean and will apply on the test data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
