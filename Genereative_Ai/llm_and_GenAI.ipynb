# %% [markdown]
# ## for LLM
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for GEN AI:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from rouge import Rouge
from nltk.translate.bleu_score import sentence_bleu

reference = "RAG is a method that improves LLMs using retrieved data."
generated = "RAG helps LLMs by retrieving relevant information."

rouge = Rouge()
scores = rouge.get_scores(generated, reference)
bleu = sentence_bleu([reference.split()], generated.split())

print("ROUGE Score:", scores)
print("BLEU Score:", bleu)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from rouge import Rouge
#       2 from nltk.translate.bleu_score import sentence_bleu
#       4 reference = "RAG is a method that improves LLMs using retrieved data."
#
# ModuleNotFoundError: No module named 'rouge'

# %%
ROUGE Score: [{'rouge-1': {'r': 0.2, 'p': 0.2857142857142857, 'f': 0.23529411280276827}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2857142857142857, 'f': 0.23529411280276827}}]
BLEU Score: 8.676910262183261e-232

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
