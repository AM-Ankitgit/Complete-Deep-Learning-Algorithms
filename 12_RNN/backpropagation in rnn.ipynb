# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Forward Propagation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# equation for farward propagation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for back propagtion we need to call the following 3 derviation with respective 3 different parameter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Problem with RNN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1 . `RNN face the long term dependcies `>>> beacsue of the vanish gradient (mean if the input length increase it wont able to rememebr for long context of the input)

# %% [markdown]
# `2. Unstable or Stangent  gradient `>>>>>>>>>> because of exploding gradient descent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# vanishing gradient problem because the your previous gradient are getting lower(mean to zero ) on recent gradient are more helpful to predict the output

# %% [markdown]
# solution:
#
# ![image.png](attachment:image.png)
